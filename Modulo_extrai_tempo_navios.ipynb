# %%
import warnings
from metodos_auxiliares_tempo_navios import TempoNaviosClass

# %load_ext autoreload
# %autoreload 2
warnings.filterwarnings("ignore")

# instancia o objetos
objeto_publicacao = TempoNaviosClass()

# publicação
objeto_publicacao.publica_conteudo()
# Out:
# 21 de agosto de 2022
# Hoje, dia 21/08/2022, em Angra dos Reis (RJ) a condição do tempo é de períodos de chuva ao longo do dia, e o por do sol será às 17:44.
#
#
#
# A temperatura esperada na cidade é de 17ºC. As temperaturas máxima e mínima esperadas são de 18ºC e 17ºC, respectivamente.
# A altura do mar esperada na cidade é de 0,7m.
# A umidade esperada na cidade é de 72%.
# A nebulosidade esperada na cidade é de 78%.
# A velocidade do vento esperada na cidade é de 10km/h.
# .
# .
# Hoje, dia 21/08/2022, em Aracaju (SE) a condição do tempo é de chuva fraca, e o por do sol será às 17:26.
#
#
#
# A temperatura esperada na cidade é de 23ºC. As temperaturas máxima e mínima esperadas são de 25ºC e 23ºC, respectivamente.
# A altura do mar esperada na cidade é de 0,8m.
# A umidade esperada na cidade é de 78%.
# A nebulosidade esperada na cidade é de 66%.
# A velocidade do vento esperada na cidade é de 28km/h.
# .
# .
# ...
